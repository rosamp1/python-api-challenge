# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0          0            waitangi -43.9535 -176.5597    283.61        74
# 1          1           grytviken -54.2811  -36.5092    267.64        94
# 2          2  severo-yeniseyskiy  60.3725   93.0408    283.57        88
# 3          3      ribeira grande  38.5167  -28.7000    295.80        91
# 4          4          sorochinsk  52.4338   53.1583    290.09        70
# ..       ...                 ...      ...       ...       ...       ...
# 586      586            macusani -14.0833  -70.4333    276.57        91
# 587      587            cidreira -30.1811  -50.2056    289.67        96
# 588      588               sitka  57.0531 -135.3300    288.09        88
# 589      589          esmeraldas -19.7625  -44.3139    292.63        66
# 590      590             bubaque  11.2833  -15.8333    300.23        83
#
#      Cloudiness  Wind Speed Country        Date
# 0            53        1.79      NZ  1691622173
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points("Lng", "Lat", geo=True, tiles = "OSM",
                                       frame_width = 800, frame_height = 600, 
                                       scale = 0.5, size = "Humidity", color = "City")

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# max temp lower than 27 degrees but higher than 21
# wind speed less than 4.5m/s
# zero cloudiness

sample_data_df = city_data_df.loc[(city_data_df["Max Temp"] > 200) & (city_data_df["Max Temp"] < 300)
                 & (city_data_df["Cloudiness"]== 0),:]
# Drop any rows with null values

sample_data_df = sample_data_df.dropna()

sample_data_df
# Display sample data
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 21        21           keflavik  64.0049  -22.5624    285.39        71
# 26        26      port mathurin -19.6833   63.4167    295.90        69
# 28        28         gadzhiyevo  69.2551   33.3362    291.20        75
# 62        62             martuk  50.7475   56.5056    289.60        79
# 97        97           hermanus -34.4187   19.2345    286.93        82
# 99        99  cavalaire-sur-mer  43.1740    6.5272    292.55        79
# 127      127              khyzy  40.9058   49.0813    298.86        49
# 128      128            beipiao  41.7919  120.7792    295.49        70
# 131      131          dashtobod  40.1269   68.4944    298.69        33
# 158      158            gaillon  49.1610    1.3402    291.94        72
# 163      163       longyearbyen  78.2186   15.6401    282.06        76
# 180      180          polyarnyy  69.1989   33.4478    291.18        75
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = sample_data_df[["City","Country","Lat","Lng", "Max Temp", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = " "

# Display sample data
hotel_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 21            keflavik      IS  64.0049  -22.5624    285.39        71
# 26       port mathurin      MU -19.6833   63.4167    295.90        69
# 28          gadzhiyevo      RU  69.2551   33.3362    291.20        75
# 62              martuk      KZ  50.7475   56.5056    289.60        79
# 97            hermanus      ZA -34.4187   19.2345    286.93        82
# 99   cavalaire-sur-mer      FR  43.1740    6.5272    292.55        79
# 127              khyzy      AZ  40.9058   49.0813    298.86        49
# 128            beipiao      CN  41.7919  120.7792    295.49        70
# 131          dashtobod      UZ  40.1269   68.4944    298.69        33
# 158            gaillon      FR  49.1610    1.3402    291.94        72
# 163       longyearbyen      SJ  78.2186   15.6401    282.06        76
# 180          polyarnyy      RU  69.1989   33.4478    291.18        75
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
#https://api.geoapify.com/v2/places?categories=public_transport.subway&filter=circle:-0.07071648508463113,51.50848194136378,1000&bias=proximity:-0.07071648508463113,51.50848194136378&limit=20&apiKey=YOUR_API_KEY

# Set parameters to search for a hotel
limit = 20
radius = 10000
#filters = f"circle:{longitude},{latitude},{radius}"
#bias = f"proximity:{longitude}, {latitude}"
#categories = "accommodation.hotel"


params = {
    "categories":"accommodation.hotel",
    "apiKey":geoapify_key, "limit":limit, "radius":radius}
    #filter":filters,
    #bias":bias
#}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    
    lat = row["Lat"]
    lon = row["Lng"]
    
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
 
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# keflavik - nearest hotel: Núpan Deluxe
# port mathurin - nearest hotel: Escale Vacances
# gadzhiyevo - nearest hotel: Оазис
# martuk - nearest hotel: No hotel found
# hermanus - nearest hotel: Aloe guest house
# cavalaire-sur-mer - nearest hotel: Hôtel La Pergola
# khyzy - nearest hotel: No hotel found
# beipiao - nearest hotel: No hotel found
# dashtobod - nearest hotel: No hotel found
# gaillon - nearest hotel: Les Canisses
# longyearbyen - nearest hotel: The Vault
# polyarnyy - nearest hotel: No hotel found
# saint-denis - nearest hotel: Residhome
# colonia - nearest hotel: Wasserturm Hotel Cologne
# lubango - nearest hotel: Novo Hotel
# feicheng - nearest hotel: No hotel found
# galich - nearest hotel: Русь-отель
# margate - nearest hotel: The Reading Rooms
# niquelandia - nearest hotel: Serrano Hotel
# balykshi - nearest hotel: Арасан
# jamestown - nearest hotel: DoubleTree Jamestown
# toliara - nearest hotel: Ambary
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points("Lng", "Lat", geo=True, tiles = "OSM",
                                       frame_width = 800, frame_height = 600, 
                                       scale = 0.5, size = "Humidity", color = "City")

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)
